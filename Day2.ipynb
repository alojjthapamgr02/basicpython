# %%
# hello

# %% [markdown]
# docstring

# %% [markdown]
# multi line comment """komeet"""

# %%
"""hello"""
# Out:
# 'hello'

# %% [markdown]
# Data types
#
# string
# integer
# float
# boolean

# %%
y = "5"
x = 5
z = 5.5
a = True

# %%
type(y)
# Out:
# str

# %%
type(x)
# Out:
# int

# %%
type(z)
# Out:
# float

# %%
type(a)
# Out:
# bool

# %%
a = int(y)

# %%
int(y) + x
# Out:
# 10

# %%
a+x
# Out:
# 10

# %%
z+x
# Out:
# 10.5

# %%
age = input("Enter the age:")
# Out:
# Enter the age: 33

# %%
type(age)
# Out:
# str

# %%
age = int(input("Enter the age:"))
# Out:
# Enter the age: 55

# %%
type(age)
# Out:
# int

# %%
name= "Aloj"
surname= "Thapa Magar"
age = 18

# %%
#fstring
print(f"My name is {name} and surname is {surname}")

print("My name is", name,"and surname is", surname)
# Out:
# My name is Aloj and surname is Thapa Magar
# My name is Aloj and surname is Thapa Magar

# %%
#dotformat
print("My name is {} {}".format(name, surname))
print("My name is {} {}".format("Aloj","Thapa Magar"))
# Out:
# My name is Aloj Thapa Magar
# My name is Aloj Thapa Magar

# %%
def root():




    return f"his query is {query} and the response generated by LLMs {response}"

# %%
a = 5
b = 10

# %%
print(f"My age is {age}")
# Out:
# My age is 18
